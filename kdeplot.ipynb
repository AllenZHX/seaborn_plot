# %%
# %matplotlib inline
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style="dark")
rs = np.random.RandomState(50)
f, axes = plt.subplots(3,3, figsize=(9,9), sharex=True, sharey=True)
for item in  axes.flat:
    print(item)
for ax, s in zip(axes.flat, np.linspace(0,3,10)):
    cmap = sns.cubehelix_palette(start=s, light=1, as_cmap=True) #color
    x,y = rs.randn(2,50)# normal distribution
    sns.kdeplot(x,y,cmap=cmap,shade=True,cut=5,ax=ax)
    ax.set(xlim=(-3,3), ylim=(-3,3))
f.tight_layout()
# Out:
# Axes(0.125,0.672059;0.227941x0.227941)
# Axes(0.398529,0.672059;0.227941x0.227941)
# Axes(0.672059,0.672059;0.227941x0.227941)
# Axes(0.125,0.398529;0.227941x0.227941)
# Axes(0.398529,0.398529;0.227941x0.227941)
# Axes(0.672059,0.398529;0.227941x0.227941)
# Axes(0.125,0.125;0.227941x0.227941)
# Axes(0.398529,0.125;0.227941x0.227941)
# Axes(0.672059,0.125;0.227941x0.227941)
